# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacation_df = pd.read_csv("Resources/Weather.csv")
vacation_df.head()
# Out:
#    Unnamed: 0               City Country  Latitude  Longitude  Temperature  \
# 0           0  sao joao da barra      BR    -21.64     -41.05        68.00
# 1           1           hermanus      ZA    -34.42      19.23        55.47
# 2           2          cape town      ZA    -33.93      18.42        49.98
# 3           5              kapaa      US     22.08    -159.32        79.70
# 4           7              vaini      TO    -21.20    -175.20        73.40
#
#    Max Temperature  Cloudiness  Humidity  Wind Speed
# 0            68.00        75.0      94.0       11.41
# 1            55.47         0.0      76.0        5.79
# 2            51.80         0.0      93.0        3.36
# 3            80.60        75.0      78.0       20.80
# 4            73.40        20.0      69.0       11.41

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
coordinates = vacation_df[["Latitude", "Longitude"]].astype(float)
humidity = vacation_df["Humidity"].astype(float)

# %%
fig = gmaps.figure(zoom_level=3, center={-33.93, 18.42})

heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Weather conditions: temp lower than 80 but higher than 70, wind speed less than 10, 0 cloudiness
best_spot_df = vacation_df
best_spot_df = best_spot_df.loc[(best_spot_df["Max Temperature"] < 80) & (best_spot_df["Max Temperature"] <70)]
best_spot_df = best_spot_df.loc[(best_spot_df["Wind Speed"] < 10)]
best_spot_df = best_spot_df.loc[(best_spot_df["Cloudiness"] == 0)]                                 
best_spot_df = best_spot_df.drop("Unnamed: 0", axis=1)
best_spot_df.head()
# Out:
#          City Country  Latitude  Longitude  Temperature  Max Temperature  \
# 1    hermanus      ZA    -34.42      19.23        55.47            55.47
# 2   cape town      ZA    -33.93      18.42        49.98            51.80
# 52   yar-sale      RU     66.83      70.83        49.03            49.03
# 71     broome      AU    -17.97     122.23        48.20            48.20
# 80   karratha      AU    -20.74     116.85        65.30            65.30
#
#     Cloudiness  Humidity  Wind Speed
# 1          0.0      76.0        5.79
# 2          0.0      93.0        3.36
# 52         0.0      85.0        5.61
# 71         0.0      93.0        3.36
# 80         0.0      41.0        6.42

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = best_spot_df
hotel_df["Hotel Name"] =""
hotel_df.head()
# Out:
#          City Country  Latitude  Longitude  Temperature  Max Temperature  \
# 1    hermanus      ZA    -34.42      19.23        55.47            55.47
# 2   cape town      ZA    -33.93      18.42        49.98            51.80
# 52   yar-sale      RU     66.83      70.83        49.03            49.03
# 71     broome      AU    -17.97     122.23        48.20            48.20
# 80   karratha      AU    -20.74     116.85        65.30            65.30
#
#     Cloudiness  Humidity  Wind Speed Hotel Name
# 1          0.0      76.0        5.79
# 2          0.0      93.0        3.36
# 52         0.0      85.0        5.61
# 71         0.0      93.0        3.36
# 80         0.0      41.0        6.42

# %%
base_url_test = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "-38.00, -57.56", #Mar de plata for testing
    "radius":  5000,
    "types": "lodging",
    "key": g_key,
}
response= requests.get(base_url_test, params=params).json()
print(json.dumps(response, indent=4))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAAPyYMkjnUPK3kyTIxSItKUDj3pvnQj9cxGTFq2HytiA1huMqBXVeF95kbn_84FuWvb3uW-lU98tKv6Bb5pi154lSyPVmwD6uUnV81voqEWjuMzdnYnox6pYYA3L3_zpC0y6ECzsVeKXRa5jr7tX7AwLHrWR-42Ov9ei76Mlvy_A1vFK4rGXvBxb8V3oLPj7rbis2RUaCYHzi8NwqoxYkxC58qiIFdbuCW7sm9JQ-D5URNlmTL7Y7D2pIA_Kj5TLkOrbeG5UT7_q-HCnuxwzHQDypoNtdLajt4WpGkubbElKanVZont8LWfdW6t6BO6lnGfo5E7MhwEL8MSIs5vYIs2BMYQOeTxS4TTJNmg4p-EJCYgj7ysWOAeqUVyL1i4r43BIQH_6apVf0AZEjq1zSpNRCwRoUa9AULwcfTxPoemorXre3y5YLv-g",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0019654,
#                     "lng": -57.5437902
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.0006786697085,
#                         "lng": -57.54249096970848
#                     },
#                     "southwest": {
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius" :  5000,
    "types" : "lodging",
    "key" : g_key,
}
for index,row in hotel_df.iterrows():
    lat= row["Latitude"]
    long= row["Longitude"]
    city_name = row["City"]
    params["location"] = f"{lat},{long}"
    print(f"Retrieving Hotel Results for Index {index}: {city_name}")
    response = requests.get(base_url, params=params).json()
    results = response["results"]
    
    try:
        print(f"Closest Hotel is {results[0]['name']}.")        
        hotel_df.loc[index, "Hotel Name"] = results[0]["name"]
        
    except (KeyError, IndexError):
        print("Missing Result... skipping")
        
    print("------------")

print("-------------------")
print("Data Complete")
print("-------------------")
# Out:
# Retrieving Hotel Results for Index 1: hermanus
# Closest Hotel is Misty Waves Boutique Hotel.
# ------------
# Retrieving Hotel Results for Index 2: cape town
# Closest Hotel is Southern Sun Waterfront Cape Town.
# ------------
# Retrieving Hotel Results for Index 52: yar-sale
# Closest Hotel is Yalemd.
# ------------
# Retrieving Hotel Results for Index 71: broome
# Closest Hotel is Mangrove Hotel.
# ------------
# Retrieving Hotel Results for Index 80: karratha
# Closest Hotel is ibis Styles Karratha.
# ------------
# Retrieving Hotel Results for Index 106: katherine
# Closest Hotel is Pine Tree Motel.
# ------------
# Retrieving Hotel Results for Index 107: bredasdorp
# Closest Hotel is Bredasdorp Country Manor.
# ------------
# Retrieving Hotel Results for Index 111: carnarvon
# Closest Hotel is Hospitality Carnarvon.
# ------------
# Retrieving Hotel Results for Index 120: chuy
# Closest Hotel is Nuevo Hotel Plaza.
# ------------
# ...

# %%
hotel_df.head()
# Out:
#          City Country  Latitude  Longitude  Temperature  Max Temperature  \
# 1    hermanus      ZA    -34.42      19.23        55.47            55.47
# 2   cape town      ZA    -33.93      18.42        49.98            51.80
# 52   yar-sale      RU     66.83      70.83        49.03            49.03
# 71     broome      AU    -17.97     122.23        48.20            48.20
# 80   karratha      AU    -20.74     116.85        65.30            65.30
#
#     Cloudiness  Humidity  Wind Speed                         Hotel Name
# 1          0.0      76.0        5.79         Misty Waves Boutique Hotel
# 2          0.0      93.0        3.36  Southern Sun Waterfront Cape Town
# 52         0.0      85.0        5.61                             Yalemd
# 71         0.0      93.0        3.36                     Mangrove Hotel
# 80         0.0      41.0        6.42               ibis Styles Karratha

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map

marker_layer = gmaps.marker_layer(locations, hover_text=(hotel_info))
fig.add_layer(marker_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
