# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacation_df = pd.read_csv("Resources/Weather.csv")
vacation_df.head()
# Out:
#    Unnamed: 0          City  Latitude  Longitude  Temperature  \
# 0           0       ushuaia    -54.80     -68.30        39.20
# 1           1  punta arenas    -53.15     -70.92        37.20
# 2           2     cape town    -33.93      18.42        62.92
# 3           3       iralaya     15.00     -83.23        80.46
# 4           4        albany     42.65     -73.76        60.44
#
#    Max Temperature  Cloudiness  Humidity  Wind Speed
# 0            39.20        40.0      80.0       33.33
# 1            37.40        81.0      80.0        5.82
# 2            64.00        40.0      67.0        4.70
# 3            80.46        98.0      84.0       10.63
# 4            63.00         1.0      93.0        1.34

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
coordinates = vacation_df[["Latitude", "Longitude"]].astype(float)
humidity = vacation_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Weather conditions: temp lower than 80 but higher than 70, wind speed less than 10, 0 cloudiness
best_spot_df = vacation_df
best_spot_df = best_spot_df.loc[(best_spot_df["Max Temperature"] < 80) & (best_spot_df["Max Temperature"] <70)]
best_spot_df = best_spot_df.loc[(best_spot_df["Wind Speed"] < 10)]
best_spot_df = best_spot_df.loc[(best_spot_df["Cloudiness"] == 0)]                                 
best_spot_df = best_spot_df.drop("Unnamed: 0", axis=1)
best_spot_df.head()
# Out:
#              City  Latitude  Longitude  Temperature  Max Temperature  \
# 14       calvinia    -31.47      19.78        59.00            59.00
# 16  alice springs    -23.70     133.88        59.00            59.00
# 49  mar del plata    -38.00     -57.56        38.28            41.00
# 52       itaituba     -4.28     -55.98        66.38            66.38
# 57     bredasdorp    -34.53      20.04        62.60            62.60
#
#     Cloudiness  Humidity  Wind Speed
# 14         0.0      44.0        3.36
# 16         0.0      18.0        6.93
# 49         0.0      77.0        4.70
# 52         0.0      69.0        1.25
# 57         0.0      59.0        8.05

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = best_spot_df
hotel_df["Hotel Name"] =""
hotel_df.head()
# Out:
#              City  Latitude  Longitude  Temperature  Max Temperature  \
# 14       calvinia    -31.47      19.78        59.00            59.00
# 16  alice springs    -23.70     133.88        59.00            59.00
# 49  mar del plata    -38.00     -57.56        38.28            41.00
# 52       itaituba     -4.28     -55.98        66.38            66.38
# 57     bredasdorp    -34.53      20.04        62.60            62.60
#
#     Cloudiness  Humidity  Wind Speed Hotel Name
# 14         0.0      44.0        3.36
# 16         0.0      18.0        6.93
# 49         0.0      77.0        4.70
# 52         0.0      69.0        1.25
# 57         0.0      59.0        8.05

# %%
base_url_test = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "-38.00, -57.56", #Mar de plata
    "radius":  5000,
    "types": "lodging",
    "key": g_key,
}
response= requests.get(base_url_test, params=params).json()
print(json.dumps(response, indent=4))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAAEL0FPVgGFTG0q-1VGk4cUHUQQn8fTm63AcbCRsT8Fhudvs-PoqJTPyf4edH9ZXvGya4pBmIdJNE2H98JOlsgl2zCIj8O2AcqaY_8oOj3eewBdf25FUVWBNiUC-qSe86SjCXX88Z4z4OBNNigWym5F9Lwqqspdmpf5wCpQDKkgyydc-ccyuSbqu9a02Ysto5jrW_ZWXlnm6ep7BtICVhX1iEBf8sH4jBxh_7j8-T-utH9jyUqNPwxs0XfQZexadGjmKinhVTYXnFpKqqU5Vb9gSuvcUipVlExfFI_dKwqR6LSzW7OP3rKH2ufkaaPou1BW10Di0J6wJMnK6uZqdqwXzKilMaybHWUJbrxX3SPs7qbrgZI3j5PPeAXvy30iGcWxIQ5YYhC_RFJViEp-_ESH9GEBoUp-3pD7C3stG6CwXQVD1C37YPO_s",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.
",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJ3QR9BBnchJURnn6wNQ170gU",
#             "plus_code": {
#                 "compound_code": "XFV3+PV Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFV3+PV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ3QR9BBnchJURnn6wNQ170gU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1707,
#             "vicinity": "Mar del Plata, Avenida Col\u00f3n 2129, FYB"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -37.99770999999999,
#                     "lng": -57.549979
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -37.9964137697085,
#                         "lng": -57.54852441970849
#                     },
#                     "southwest": {
#                         "lat": -37.9991117302915,
#                         "lng": -57.5512223802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "41a887830ee565dfa20726d30812ea2ef1ab778d",
#             "name": "Gran Hotel Panamericano",
#             "photos": [
#                 {
#                     "height": 682,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117043961811068637584\">Gran Hotel Panamericano</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADCL8WJNffZGzVJTV-Q_EClyobBVSLyBU1lR0o_W8Jbn3ncGqlNy92MGbqb3VSFbe2pxp3GZY5ukcBHxkaLj2IDyIVkeYM3DTtdnkVFpGexsOSP8sVq9R22W4-PctTqHoEhC3QbkYkcHUdnpniybmCCAjGhQLEAm21IuVaokZ-ZSvV45ytxiZ_A",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJab-tqAPchJURHvLNZuqXet4",
#             "plus_code": {
#                 "compound_code": "2F22+W2 Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48J42F22+W2"
#             },
#             "rating": 4.1,
#             "reference": "ChIJab-tqAPchJURHvLNZuqXet4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 883,
#             "vicinity": "DOM, Hip\u00f3lito Yrigoyen 1683, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0085567,
#                     "lng": -57.5414561
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.00717926970849,
#                         "lng": -57.54016431970849
#                     },
#                     "southwest": {
#                         "lat": -38.00987723029149,
#                         "lng": -57.54286228029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "67a7d8039b8e7153a7fd03ad60ca669528daeacb",
#             "name": "Hotel Luz y Fuerza",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111149342035863902273\">Carlos Emanuel Gonzalez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAWeKZCx9Vh-6UNivQWKXVg9Y8CP7dFxzfd_-gcijLM3qW5gUCDCt6n6c-2t59hj6OexThdzi7qWk1KhK6jqxNsSQUArGdPaGUHFD2fAvj40pM02YRapjmQ6d9FwdRtPhYEhDK_odrrSCaA6Nxy0D-kbCqGhS-wDiY4UFw5PXrGoorIgdp-5Ge8Q",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJhZXVST3chJURQccTyDvmjpU",
#             "plus_code": {
#                 "compound_code": "XFR5+HC Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFR5+HC"
#             },
#             "rating": 3.9,
#             "reference": "ChIJhZXVST3chJURQccTyDvmjpU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1529,
#             "vicinity": "Mar del Plata, Las Heras 2256, EID"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0017495,
#                     "lng": -57.5426875
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.00040051970849,
#                         "lng": -57.5413385197085
#                     },
#                     "southwest": {
#                         "lat": -38.00309848029149,
#                         "lng": -57.5440364802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "56ee101b87bbd69a1d6620a1c2fef067c05c0d5f",
#             "name": "Bristol Condominio Apart Hotel",
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113718083763658246196\">Bristol Condominio Apart Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAf_SQmo0eUfZZPwWuDw2C0OBR5Tr_wGcmvB3ur0oZ9Gj3kDycdVQjlLyb19casgk0jPf3cb9GPaJrsR8uM9UKUujzaQOM44OrctbgBolBTSJmflJRm7A5mThTj_dT-1KwEhA_L1EuJDko-ljAcHTPOJ87GhQ4Ag8oKgxXTyLUqRmttXTst8nI0g",
#                     "width": 3072
#                 }
#             ],
#             "place_id": "ChIJOdn-qAPchJURSPOUzf9KosI",
#             "plus_code": {
#                 "compound_code": "XFX4+8W Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFX4+8W"
#             },
#             "rating": 4.4,
#             "reference": "ChIJOdn-qAPchJURSPOUzf9KosI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1322,
#             "vicinity": "Calle San Mart\u00edn 2150, Centro, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -37.9707534,
#                     "lng": -57.54390839999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -37.9694511697085,
#                         "lng": -57.54246611970849
#                     },
#                     "southwest": {
#                         "lat": -37.9721491302915,
#                         "lng": -57.54516408029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a14997611d98b7197f165302f1d2a0c53b52bdfb",
#             "name": "Hotel Caril\u00f3",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106186491914853518131\">Lilian Cortti</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAc_mfi35CA54qwE4sXV4-h-aVT4kV4AEEjaphYN72rtG8aQKGqm8rM4fF1rSfeny7z6V4A_mRM6E2sSMxUGpwtadscT3oCURwns-OLx1LjqvsaunVGhVir8hyk4cOT3gNEhCCJYYJ0FPtp0PjcmEWQ88iGhSiE6yNTxjEgoTi6DxuaSuRMezpYw",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJyZ-pjefbhJURR7dLNcVGLg4",
#             "plus_code": {
#                 "compound_code": "2FH4+MC Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48J42FH4+MC"
#             },
#             "rating": 3.8,
#             "reference": "ChIJyZ-pjefbhJURR7dLNcVGLg4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 258,
#             "vicinity": "Av. Constituci\u00f3n 4002, Perla Norte, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0153705,
#                     "lng": -57.5413193
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.0139975697085,
#                         "lng": -57.5400212697085
#                     },
#                     "southwest": {
#                         "lat": -38.01669553029149,
#                         "lng": -57.5427192302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dcdad73b6493a44f6df786729f60af61eafb726f",
#             "name": "Hotel Sainte Jeanne",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108297367427333872013\">Marcela PG</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4hcyVH_dxxifSI-L3LtqOtK6dydg3HTmvjaFjf4B5Nmnf9NdM6wRGR_CuYowMBfYCaveMlbfRnSWHlIDtKdvqXWfPTT8VwKIubzhRiLPYL9dt0al_4Vi3sCEvCcHevaNEhD4aUNUKqItpo7zVE-CYe75GhTioND-z59jQ6PtIfKuPHoEVLBZiQ",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJeW5mzzrchJUR6vsYtvxHdlM",
#             "plus_code": {
#                 "compound_code": "XFM5+VF Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFM5+VF"
#             },
#             "rating": 4.6,
#             "reference": "ChIJeW5mzzrchJUR6vsYtvxHdlM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2228,
#             "vicinity": "DAB, Mart\u00edn Miguel de G\u00fcemes 2850, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.00761060000001,
#                     "lng": -57.5444742
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.0062423197085,
#                         "lng": -57.5431093697085
#                     },
#                     "southwest": {
#                         "lat": -38.0089402802915,
#                         "lng": -57.54580733029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4abb8db6a8b04a70c3995702d62f0c51c20e93c8",
#             "name": "Hotel Neptuno",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110271610237489645575\">Hotel Neptuno</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgsB5he8NfCY7mKpCxMiG-nJwW1j95bKBiRz2A3-yb-oIxjz_U8VXoaBzRu5wY613YJ-AypEzBaU0S87TQpFuEhu2IcW8p0dsJ2RIVpKOpewrbzoOhrPjt1gtAHyCW17XEhBMXe2r1TINOEOCwQL4ijrZGhQaZA6n3YzGk6CKwmDf9lLIX37-Mg",
#                     "width": 910
#                 }
#             ],
#             "place_id": "ChIJQZPBZBjchJURlyrIeAknjDQ",
#             "plus_code": {
#                 "compound_code": "XFR4+X6 Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFR4+X6"
#             },
#             "rating": 3.7,
#             "reference": "ChIJQZPBZBjchJURlyrIeAknjDQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 351,
#             "vicinity": "Almirante Brown 1958, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -37.9969341,
#                     "lng": -57.5499483
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -37.99550536970849,
#                         "lng": -57.5485346197085
#                     },
#                     "southwest": {
#                         "lat": -37.99820333029149,
#                         "lng": -57.55123258029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "158f824d5157e9bb2e87cab531a8ec131aaed4ac",
#             "name": "Hotel Espa\u00f1a",
#             "photos": [
#                 {
#                     "height": 534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100173302268116023755\">Hotel Espa\u00f1a</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJzXO6T0-UNfEOAzZ9bpsuJSWlMvhh5ZabA9op3wCRYlC7TQ2IXvEMfrZCVRhTJ1QmbNSAEfSinsHg6VoV3lbJKRhWH6xkBLE0PSSRMMDHnNHH1zVF9ANe0aDMy_SYpKCEhDF3ebTN00gfSjjWG8fbIlmGhT2FxXqo5zfG_TBSJrPepVNRug66A",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJKxlpyAPchJURh6kEbrvhuvU",
#             "plus_code": {
#                 "compound_code": "2F32+62 Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48J42F32+62"
#             },
#             "rating": 4.1,
#             "reference": "ChIJKxlpyAPchJURh6kEbrvhuvU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 756,
#             "vicinity": "Av Pedro Luro 2964, Centro, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0318296,
#                     "lng": -57.53971310000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.0305637197085,
#                         "lng": -57.5381948697085
#                     },
#                     "southwest": {
#                         "lat": -38.0332616802915,
#                         "lng": -57.54089283029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9435730d0129587380ad02b2de00da18bfa7e673",
#             "name": "Sheraton Mar del Plata Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109872217718742351183\">Sheraton Mar del Plata Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwhSunaYghQzNT-xV-ZdVMSa2rgr_JUVQE-lQqCw_caEQHTGI_8PDXSrQ6DTjy68EVn9KMsvX5cP-y-Vimc5CE1SAUHCRxbEuhb7bkj0Dh7rpyernANiI7hKUwinlGJFZEhAh9CROv0pTCmCF-UQsm4B3GhSaR6nbDC7hQO35Dug1v6ocHytI-w",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJv4LtX87dhJURMdesXbvwrpI",
#             "plus_code": {
#                 "compound_code": "XF96+74 Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XF96+74"
#             },
#             "rating": 4.4,
#             "reference": "ChIJv4LtX87dhJURMdesXbvwrpI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3473,
#             "vicinity": "Leandro N. Alem 4221, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -37.993808,
#                     "lng": -57.547791
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -37.9924261197085,
#                         "lng": -57.5465063697085
#                     },
#                     "southwest": {
#                         "lat": -37.9951240802915,
#                         "lng": -57.54920433029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "14699280f3b5aee32c96061fba8f916f7cf2abbf",
#             "name": "Hotel Brunetti",
#             "photos": [
#                 {
#                     "height": 2491,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104576131939356576548\">Hotel Brunetti</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApvSbFAfNGu_UalkrhAbrbMF0UgJEYUJ3KkDt8Rouuw330T2si5o_rQt4gRFXtDOWN9tiWZ9HzP4mFbSgwwD6cEoZ8rFn1h_D9L7T5j41LKedj5c2HOhd0vdd6cnatcVoEhAmakV73ysvsyrHoYGNnm50GhTLzJzlVBr2ib5mrcmZnmlpfGmCyA",
#                     "width": 4240
#                 }
#             ],
#             "place_id": "ChIJWy9PNAHchJURDa_KVF_-8s4",
#             "plus_code": {
#                 "compound_code": "2F42+FV Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48J42F42+FV"
#             },
#             "rating": 3.8,
#             "reference": "ChIJWy9PNAHchJURDa_KVF_-8s4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 174,
#             "vicinity": "La Rioja 1250, Mar del Plata"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -38.0025219,
#                     "lng": -57.54561340000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -38.00110651970849,
#                         "lng": -57.5442112197085
#                     },
#                     "southwest": {
#                         "lat": -38.00380448029149,
#                         "lng": -57.54690918029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c49ec7961335793ade9e2ef164c4667409f8132b",
#             "name": "San Remo Grand Hotel",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100192643739227344026\">JORGE CUBAS</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFHogl9c-cDSnSao9Tfa4a5Jomx5jC0IzY3cO2_HzX4UmdoMMMbqhXISQFOeEtbsU1VMEyDJ5m--fvKZTYBLSGz36cSbJxItI_l7bkzAIN152nfxvPg9ej5KyBe5VzoZhEhAGSDiEKBX1Ur9L6qQlRSmQGhSm8WsBUHOUUK2p-LBP3iv9juV5lw",
#                     "width": 3984
#                 }
#             ],
#             "place_id": "ChIJQ1ppff3YhJURFSEcm_jtxPI",
#             "plus_code": {
#                 "compound_code": "XFW3+XQ Mar del Plata, Buenos Aires Province, Argentina",
#                 "global_code": "48H4XFW3+XQ"
#             },
#             "rating": 3.5,
#             "reference": "ChIJQ1ppff3YhJURFSEcm_jtxPI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1690,
#             "vicinity": "Belgrano 2338, Centro, Mar del Plata"
#         }
#     ],
#     "status": "OK"
# }

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius" :  5000,
    "types" : "lodging",
    "key" : g_key,
}
for index,row in hotel_df.iterrows():
    lat= row["Latitude"]
    long= row["Longitude"]
    city_name = row["City"]
    params["location"] = f"{lat},{long}"
    print(f"Retrieving Hotel Results for Index {index}: {city_name}")
    response = requests.get(base_url, params=params).json()
    results = response["results"]
    
    try:
        print(f"Closest Hotel is {results[0]['name']}.")        
        hotel_df.loc[index, "Hotel Name"] = results[0]["name"]
        
    except (KeyError, IndexError):
        print("Missing Result... skipping")
        
    print("------------")
# Out:
# Retrieving Hotel Results for Index 14: calvinia
# Closest Hotel is Die Lemoenhuis.
# ------------
# Retrieving Hotel Results for Index 16: alice springs
# Closest Hotel is Desert Palms Alice Springs.
# ------------
# Retrieving Hotel Results for Index 49: mar del plata
# Closest Hotel is Gran Hotel Mar del Plata habitaciones.
# ------------
# Retrieving Hotel Results for Index 52: itaituba
# Closest Hotel is Hotel Campos.
# ------------
# Retrieving Hotel Results for Index 57: bredasdorp
# Closest Hotel is Bredasdorp Country Manor.
# ------------
# Retrieving Hotel Results for Index 65: ecoporanga
# Closest Hotel is Hotel e Restaurante Dico.
# ------------
# Retrieving Hotel Results for Index 73: alyangula
# Closest Hotel is Groote Eylandt Lodge.
# ------------
# Retrieving Hotel Results for Index 81: saskylakh
# Missing Result... skipping
# ------------
# Retrieving Hotel Results for Index 87: saldanha
# Closest Hotel is Blue Bay Lodge.
# ------------
# Retrieving Hotel Results for Index 119: moranbah
# Closest Hotel is Direct Hotels - Monterey Moranbah.
# ------------
# Retrieving Hotel Results for Index 130: marataizes
# Closest Hotel is Ed. Barra Shopping.
# ------------
# Retrieving Hotel Results for Index 131: comodoro rivadavia
# Closest Hotel is Austral Hotel.
# ------------
# Retrieving Hotel Results for Index 134: lebu
# Closest Hotel is Hostal Las Lilas.
# ------------
# Retrieving Hotel Results for Index 170: chuy
# Closest Hotel is Nuevo Hotel Plaza.
# ------------
# Retrieving Hotel Results for Index 178: cherskiy
# Closest Hotel is Gostinitsa.
# ------------
# Retrieving Hotel Results for Index 180: sao joao da barra
# Closest Hotel is Pousada Porto De Canoas.
# ------------
# Retrieving Hotel Results for Index 198: mareeba
# Closest Hotel is Trinity Plains Tourist Park.
# ------------
# Retrieving Hotel Results for Index 207: necochea
# Closest Hotel is dyd -mar Hotel.
# ------------
# Retrieving Hotel Results for Index 220: rawson
# Closest Hotel is Hotel Punta León.
# ------------
# Retrieving Hotel Results for Index 249: port lincoln
# Closest Hotel is Port Lincoln Hotel.
# ------------
# Retrieving Hotel Results for Index 255: emerald
# Closest Hotel is The Irish Village.
# ------------
# Retrieving Hotel Results for Index 266: esmeraldas
# Closest Hotel is Hotel Fazenda Lagoa Azul.
# ------------
# Retrieving Hotel Results for Index 267: santa maria
# Closest Hotel is Hotel Morotin.
# ------------
# Retrieving Hotel Results for Index 284: vallenar
# Closest Hotel is Humacao Bed & Breakfast.
# ------------
# Retrieving Hotel Results for Index 296: grajau
# Closest Hotel is Hotel Confiança.
# ------------
# Retrieving Hotel Results for Index 298: bell ville
# Closest Hotel is Hotel Central.
# ------------
# Retrieving Hotel Results for Index 307: vila velha
# Closest Hotel is Hotel Vitória Palace.
# ------------
# Retrieving Hotel Results for Index 318: eureka
# Closest Hotel is Eureka Inn Trademark By Wyndham.
# ------------
# Retrieving Hotel Results for Index 319: constitucion
# Closest Hotel is Hotel Boutique Las Azucenas.
# ------------
# Retrieving Hotel Results for Index 326: chimbarongo
# Closest Hotel is Hostal Ruka Kamañ.
# ------------
# Retrieving Hotel Results for Index 357: linhares
# Closest Hotel is Hotel Conceição.
# ------------
# Retrieving Hotel Results for Index 426: swellendam
# Closest Hotel is De Kloof Luxury Estate boutique Hotel & SPA.
# ------------
# Retrieving Hotel Results for Index 430: broken hill
# Closest Hotel is Daydream Motel & Cottages.
# ------------
# Retrieving Hotel Results for Index 443: urucara
# Closest Hotel is Pousada Maria Bonita.
# ------------
# Retrieving Hotel Results for Index 444: salta
# Closest Hotel is Hotel Alejandro I.
# ------------
# Retrieving Hotel Results for Index 445: buenos aires
# Closest Hotel is Gran Hotel Argentino.
# ------------
# Retrieving Hotel Results for Index 471: batagay
# Missing Result... skipping
# ------------
# Retrieving Hotel Results for Index 473: santiago
# Closest Hotel is Hotel Panamericano.
# ------------
# Retrieving Hotel Results for Index 476: riachao das neves
# Closest Hotel is Casa de vó Dina.
# ------------
# Retrieving Hotel Results for Index 499: victoria point
# Closest Hotel is Bay Retreat Motel.
# ------------
# Retrieving Hotel Results for Index 512: concordia
# Closest Hotel is Palmar Hotel Casino.
# ------------

# %%
hotel_df.head()
# Out:
#              City  Latitude  Longitude  Temperature  Max Temperature  \
# 14       calvinia    -31.47      19.78        59.00            59.00
# 16  alice springs    -23.70     133.88        59.00            59.00
# 49  mar del plata    -38.00     -57.56        38.28            41.00
# 52       itaituba     -4.28     -55.98        66.38            66.38
# 57     bredasdorp    -34.53      20.04        62.60            62.60
#
#     Cloudiness  Humidity  Wind Speed                             Hotel Name
# 14         0.0      44.0        3.36                         Die Lemoenhuis
# 16         0.0      18.0        6.93             Desert Palms Alice Springs
# 49         0.0      77.0        4.70  Gran Hotel Mar del Plata habitaciones
# 52         0.0      69.0        1.25                           Hotel Campos
# 57         0.0      59.0        8.05               Bredasdorp Country Manor

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-58-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Country'

# %%
# Add marker layer ontop of heat map


# Display figure
