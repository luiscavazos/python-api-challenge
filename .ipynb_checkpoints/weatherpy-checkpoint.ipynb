# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key_2

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Testing the API in order to confirm location of information required
base_url = "https://api.openweathermap.org/data/2.5/weather?"
test_url= base_url + "appid=" + weather_api_key_2 + "&q=london&units=imperial"
response= requests.get(test_url).json()
print(response)
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.05, 'feels_like': 68.59, 'temp_min': 70, 'temp_max': 75.99, 'pressure': 1016, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1596145670, 'sys': {'type': 1, 'id': 1414, 'country': 'GB', 'sunrise': 1596082902, 'sunset': 1596138719}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
#Have to have lists in order to save information
lat= []
long=[]
temp=[]
temp_max= []
humidity =[]
cloudiness= []
wind_speed=[]
count=0
set=0

# use iterrows to iterate through pandas dataframe, adding NaN append in order to have same length array for DataFrame

for city in cities:

    query_url= base_url + "appid=" + weather_api_key_2 + "&q= "+ city + "&units=imperial"

    
    print(f"Beginning Bat-Data Retrieval.")
    print("-----------------")
    count = count + 1
    if count == 51:
        count=1
        set = set +1
        time.sleep(5)
    print(f"Processing Record " + str(count) + " of Set " + str(set) + " | " + city)
    try:
        response = requests.get(query_url).json()
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        temp_max.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
    except KeyError:
        print("City not found. Searching for next city...")
        lat.append(np.nan)
        long.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
print("---------------------")
print("Bat-Data Retrieval Complete")
print("---------------------")
# Out:
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 1 of Set 0 | tuktoyaktuk
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 2 of Set 0 | busselton
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 3 of Set 0 | unhel
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 4 of Set 0 | norman wells
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 5 of Set 0 | bose
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 6 of Set 0 | klaksvik
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 7 of Set 0 | nouadhibou
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 8 of Set 0 | barrow
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 9 of Set 0 | dikson
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 10 of Set 0 | taolanaro
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 11 of Set 0 | butaritari
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 12 of Set 0 | cherskiy
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 13 of Set 0 | rundu
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 14 of Set 0 | port alfred
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 15 of Set 0 | torbay
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 16 of Set 0 | pevek
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 17 of Set 0 | marzuq
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 18 of Set 0 | victoria
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 19 of Set 0 | ushuaia
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 20 of Set 0 | punta arenas
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 21 of Set 0 | bengkulu
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 22 of Set 0 | bandundu
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 23 of Set 0 | atuona
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 24 of Set 0 | amderma
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 25 of Set 0 | cape town
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 26 of Set 0 | bandarbeyla
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 27 of Set 0 | new norfolk
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 28 of Set 0 | mataura
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 29 of Set 0 | lavrentiya
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 30 of Set 0 | albany
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 31 of Set 0 | maniitsoq
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 32 of Set 0 | fairbanks
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 33 of Set 0 | kavieng
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 34 of Set 0 | manzhouli
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 35 of Set 0 | tsihombe
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 36 of Set 0 | airai
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 37 of Set 0 | nabire
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 38 of Set 0 | san patricio
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 39 of Set 0 | nosy varika
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 40 of Set 0 | hermanus
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 41 of Set 0 | east london
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 42 of Set 0 | grand river south east
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 43 of Set 0 | saleaula
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 44 of Set 0 | tasiilaq
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 45 of Set 0 | boulder city
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 46 of Set 0 | hithadhoo
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 47 of Set 0 | saint-philippe
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 48 of Set 0 | ruatoria
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 49 of Set 0 | novyy svit
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 50 of Set 0 | bethel
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 1 of Set 1 | mocambique
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 2 of Set 1 | saskylakh
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 3 of Set 1 | barentsburg
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 4 of Set 1 | khatanga
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 5 of Set 1 | kuching
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 6 of Set 1 | sao joao da barra
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 7 of Set 1 | basco
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 8 of Set 1 | lasa
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 9 of Set 1 | ixtapa
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 10 of Set 1 | kismayo
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 11 of Set 1 | kroonstad
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 12 of Set 1 | inuvik
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 13 of Set 1 | cidreira
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 14 of Set 1 | yellowknife
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 15 of Set 1 | mayumba
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 16 of Set 1 | ambon
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 17 of Set 1 | sakakah
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 18 of Set 1 | belushya guba
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 19 of Set 1 | daru
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 20 of Set 1 | reyes
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 21 of Set 1 | hamilton
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 22 of Set 1 | gdynia
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 23 of Set 1 | benguela
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 24 of Set 1 | souillac
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 25 of Set 1 | kapaa
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 26 of Set 1 | samusu
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 27 of Set 1 | qaanaaq
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 28 of Set 1 | raga
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 29 of Set 1 | oktyabrskiy
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 30 of Set 1 | rikitea
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 31 of Set 1 | varnavino
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 32 of Set 1 | cairns
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 33 of Set 1 | pontianak
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 34 of Set 1 | alyangula
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 36 of Set 1 | castro
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 37 of Set 1 | bredasdorp
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 38 of Set
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 10 of Set 11 | talaya
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 11 of Set 11 | djibo
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 12 of Set 11 | kisanga
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 13 of Set 11 | hirara
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 14 of Set 11 | winslow
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 15 of Set 11 | pathein
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 16 of Set 11 | khawhai
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 17 of Set 11 | kyzyl-suu
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 18 of Set 11 | bababe
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 19 of Set 11 | homer
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 20 of Set 11 | trenggalek
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 21 of Set 11 | santa eulalia del rio
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 22 of Set 11 | tacuarembo
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 23 of Set 11 | sakaiminato
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 24 of Set 11 | peace river
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 25 of Set 11 | kuche
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 26 of Set 11 | iskateley
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 27 of Set 11 | mana
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 28 of Set 11 | ondorhaan
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 29 of Set 11 | tilichiki
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 30 of Set 11 | denpasar
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 31 of Set 11 | sovetskaya
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 32 of Set 11 | emerald
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 33 of Set 11 | arona
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 34 of Set 11 | longyan
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 35 of Set 11 | minab
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 36 of Set 11 | gillette
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 37 of Set 11 | zyryanka
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 38 of Set 11 | wangjing
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 39 of Set 11 | asfi
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 40 of Set 11 | cumberland
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 41 of Set 11 | vila franca do campo
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 42 of Set 11 | shizukuishi
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 43 of Set 11 | frontino
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 44 of Set 11 | camocim
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 45 of Set 11 | abu samrah
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 46 of Set 11 | auki
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 47 of Set 11 | xining
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 48 of Set 11 | sanandaj
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 49 of Set 11 | imbituva
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 50 of Set 11 | banmo
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 1 of Set 12 | shar
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 2 of Set 12 | podor
# City not found. Searching for next city...
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 3 of Set 12 | villa carlos paz
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 4 of Set 12 | rio grande
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 5 of Set 12 | grindavik
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 6 of Set 12 | puerto penasco
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 7 of Set 12 | benbrook
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 8 of Set 12 | grand gaube
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 9 of Set 12 | kirakira
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 10 of Set 12 | inirida
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 11 of Set 12 | tazmalt
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 12 of Set 12 | strakonice
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 13 of Set 12 | singleton
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 14 of Set 12 | ayagoz
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 15 of Set 12 | waitati
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 16 of Set 12 | pulandian
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 17 of Set 12 | nelson bay
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 18 of Set 12 | kanbe
# Beginning Bat-Data Retrieval.
# -----------------
# Processing Record 19 of Set 12 | forbes
# ---------------------
# Bat-Data Retrieval Complete
# ---------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Printing value len of values to confirm they are same lenght to avoid array error when creating Dataframe.
print(len(cities), len(lat), len(temp), len(cloudiness), len(humidity), len(wind_speed))
# Out:
# 619 619 619 619 619 619

# %%
#Created DataFrame and removed cities with NaN values

weather_df = pd.DataFrame({"City" : cities, "Latitude" : lat, "Longitude" : long,  "Temperature" : temp, "Max Temperature" : temp_max, "Cloudiness" : cloudiness, "Humidity" : humidity, "Wind Speed" : wind_speed})
weather_df = weather_df.dropna(how="any")
#weather_df.count()
weather_df.to_csv("Resources/Weather.csv")
weather_df.head()
# Out:
#            City  Latitude  Longitude  Temperature  Max Temperature  \
# 0   tuktoyaktuk     69.45    -133.04        62.60            62.60
# 1     busselton    -33.65     115.33        49.62            50.00
# 2         unhel     23.33      75.57        78.22            78.22
# 3  norman wells     65.28    -126.83        73.40            73.40
# 5      klaksvik     62.23      -6.59        50.00            50.00
#
#    Cloudiness  Humidity  Wind Speed
# 0        90.0      72.0        8.05
# 1        27.0      85.0        8.08
# 2        99.0      87.0        6.02
# 3        75.0      56.0       10.29
# 5       100.0      93.0       13.87

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Running a describe in order to see each columns values, seeing max value in Humidity column as 100 means
# that there are no cities with humidity > 100, skipping step.
weather_df.describe()
# Out:
#          Latitude   Longitude  Temperature  Max Temperature  Cloudiness  \
# count  537.000000  537.000000   537.000000       537.000000  537.000000
# mean    18.254600   24.104935    67.453762        67.864730   47.778399
# std     34.452733   91.737229    14.393669        14.535898   38.906620
# min    -54.800000 -175.200000    30.990000        30.990000    0.000000
# 25%    -10.170000  -55.980000    55.400000        55.510000    4.000000
# 50%     20.930000   25.680000    69.400000        69.800000   41.000000
# 75%     48.430000  109.250000    78.440000        78.800000   87.000000
# max     78.220000  179.320000   109.170000       109.400000  100.000000
#
#          Humidity  Wind Speed
# count  537.000000  537.000000
# mean    72.527002    7.435549
# std     20.619232    4.995835
# min      3.000000    0.040000
# 25%     61.000000    3.710000
# 50%     78.000000    6.040000
# 75%     88.000000   10.290000
# max    100.000000   50.600000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, temp_max, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Latitude vs. Max Temperature")
plt.savefig("Resources/latvstemp.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs. Humidity")
plt.savefig("Resources/latvshum.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs. Humidity")
plt.savefig("Resources/latvscloud.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed")
plt.savefig("Resources/latvswind.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = weather_df[weather_df["Latitude"] >0]
northern_df.head()
# Out:
#            City  Latitude  Longitude  Temperature  Max Temperature  \
# 0   tuktoyaktuk     69.45    -133.04        62.60            62.60
# 2         unhel     23.33      75.57        78.22            78.22
# 3  norman wells     65.28    -126.83        73.40            73.40
# 5      klaksvik     62.23      -6.59        50.00            50.00
# 6    nouadhibou     20.93     -17.03        73.40            73.40
#
#    Cloudiness  Humidity  Wind Speed
# 0        90.0      72.0        8.05
# 2        99.0      87.0        6.02
# 3        75.0      56.0       10.29
# 5       100.0      93.0       13.87
# 6        40.0      88.0        6.93

# %%
southern_df = weather_df[weather_df["Latitude"]<0 ]
southern_df.head()
# Out:
#             City  Latitude  Longitude  Temperature  Max Temperature  \
# 1      busselton    -33.65     115.33        49.62            50.00
# 12         rundu    -17.93      19.77        54.54            54.54
# 13   port alfred    -33.59      26.89        56.71            56.71
# 18       ushuaia    -54.80     -68.30        31.17            31.17
# 19  punta arenas    -53.15     -70.92        37.20            37.40
#
#     Cloudiness  Humidity  Wind Speed
# 1         27.0      85.0        8.08
# 12         0.0      41.0        5.75
# 13        27.0      85.0        7.63
# 18        56.0      94.0        4.43
# 19        40.0      86.0       12.75

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
ntl_slope, ntl_int, ntl_r, ntl_p, ntl_std_err = linregress(northern_df["Latitude"], northern_df["Max Temperature"])
ntl_fit = ntl_slope * northern_df["Latitude"] + ntl_int
line_eq_ntl = "y = " + str(round(ntl_slope,2)) + "x + " + str(round(ntl_int,2)) #???
plt.scatter(northern_df["Latitude"],northern_df["Max Temperature"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_ntl,(6,10),fontsize=15,color="red") #???
plt.plot(northern_df["Latitude"],ntl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere - Latitude vs. Max Temperature")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
stl_slope, stl_int, stl_r, stl_p, stl_std_err = linregress(southern_df["Latitude"], southern_df["Max Temperature"])
stl_fit = stl_slope * southern_df["Latitude"] + stl_int
line_eq_stl = "y = " + str(round(stl_slope,2)) + "x + " + str(round(stl_int,2)) #???
plt.scatter(southern_df["Latitude"],southern_df["Max Temperature"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_stl,(6,10),fontsize=15,color="red") #???
plt.plot(southern_df["Latitude"],stl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere - Latitude vs. Max Temperature")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
nhl_slope, nhl_int, nhl_r, nhl_p, nhl_std_err = linregress(northern_df["Latitude"], northern_df["Humidity"])
nhl_fit = nhl_slope * northern_df["Latitude"] + nhl_int
line_eq_nhl = "y = " + str(round(nhl_slope,2)) + "x + " + str(round(nhl_int,2))
plt.scatter(northern_df["Latitude"],northern_df["Humidity"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_nhl,(6,10),fontsize=15,color="red")
plt.plot(northern_df["Latitude"],nhl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere - Latitude vs. Humidity")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
shl_slope, shl_int, shl_r, shl_p, shl_std_err = linregress(southern_df["Latitude"], southern_df["Humidity"])
shl_fit = shl_slope * southern_df["Latitude"] + shl_int
line_eq_shl = "y = " + str(round(shl_slope,2)) + "x + " + str(round(shl_int,2)) #???
plt.scatter(southern_df["Latitude"],southern_df["Humidity"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_shl,(6,10),fontsize=15,color="red") #???
plt.plot(southern_df["Latitude"],shl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Latitude vs. Humidity")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
ncl_slope, ncl_int, ncl_r, ncl_p, ncl_std_err = linregress(northern_df["Latitude"], northern_df["Cloudiness"])
ncl_fit = ncl_slope * northern_df["Latitude"] + ncl_int
line_eq_ncl = "y = " + str(round(ncl_slope,2)) + "x + " + str(round(ncl_int,2))
plt.scatter(northern_df["Latitude"],northern_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_ncl,(6,10),fontsize=15,color="red")
plt.plot(northern_df["Latitude"],ncl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere - Latitude vs. Cloudiness")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scl_slope, scl_int, scl_r, scl_p, scl_std_err = linregress(southern_df["Latitude"], southern_df["Cloudiness"])
scl_fit = scl_slope * southern_df["Latitude"] + scl_int
line_eq_scl = "y = " + str(round(scl_slope,2)) + "x + " + str(round(scl_int,2)) #???
plt.scatter(southern_df["Latitude"],southern_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_scl,(6,10),fontsize=15,color="red") #???
plt.plot(southern_df["Latitude"],scl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Latitude vs. Cloudiness")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
nwl_slope, nwl_int, nwl_r, nwl_p, nwl_std_err = linregress(northern_df["Latitude"], northern_df["Wind Speed"])
nwl_fit = nwl_slope * northern_df["Latitude"] + nwl_int
line_eq_nwl = "y = " + str(round(nwl_slope,2)) + "x + " + str(round(nwl_int,2))
plt.scatter(northern_df["Latitude"],northern_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_nwl,(6,10),fontsize=15,color="red")
plt.plot(northern_df["Latitude"],nwl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere - Latitude vs. Wind Speed")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
swl_slope, swl_int, swl_r, swl_p, swl_std_err = linregress(southern_df["Latitude"], southern_df["Wind Speed"])
swl_fit = swl_slope * southern_df["Latitude"] + swl_int
line_eq_swl = "y = " + str(round(swl_slope,2)) + "x + " + str(round(swl_int,2)) #???
plt.scatter(southern_df["Latitude"],southern_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.annotate(line_eq_swl,(6,10),fontsize=15,color="red") #???
plt.plot(southern_df["Latitude"],swl_fit,"--")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere - Latitude vs. Wind Speed")
plt.show()
